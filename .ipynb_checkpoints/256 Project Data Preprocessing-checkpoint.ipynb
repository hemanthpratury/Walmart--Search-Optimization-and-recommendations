# %%
import pandas as pd
import numpy as np

# %%
    input_folder_path= r"C:\Users\Hemanth"

    filename = "\WalmartDatasset.txt"
    
    header_names=["term","product_id", "language","product_impressions","Product_clicks","cart_adds","cart_start","checkout","order"]
    df_dly_hdp = pd.read_csv(input_folder_path+filename, sep='\t', names = header_names)

# %%
    # filter out French language records
    df_dly_hdp = (df_dly_hdp[df_dly_hdp['language'] == 'English'])

    joined_df_dly = (
    df_dly_hdp[['term', 'product_id', 'product_impressions', 'Product_clicks', 'cart_adds', 'checkout', 'order']])

# %%
# print(df_dly_hdp)


joined_df_dly['searchTerm'] = joined_df_dly['term']
joined_df_dly['ATR'] = joined_df_dly['cart_adds'] / joined_df_dly['product_impressions']
joined_df_dly['CTR'] = joined_df_dly['Product_clicks'] / joined_df_dly['product_impressions']
joined_df_dly['conv'] = joined_df_dly['order'] / joined_df_dly['product_impressions']

columns_all = ['searchTerm', 'product_id', 'product_impressions', 'Product_clicks', 'cart_adds', 'order', 'CTR', 'ATR',
               'conv']
# Out:
# C:\Users\Hemanth\anaconda_instll\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# columns for input

joined_df_dly = joined_df_dly[list(columns_all)].reset_index()

print(joined_df_dly.info())

###########################################3

# print(joined_df_dly.tail(50))

# Concat null results and positive results - Final step

# columns for input

final_merged_dataset = joined_df_dly[list(columns_all)]
final_merged_dataset = final_merged_dataset.replace(np.nan, 0)
final_merged_dataset = final_merged_dataset.drop_duplicates()

final_merged_dataset.to_csv(r'C:\Users\Hemanth\final_merged_dataset_mthly2_test.csv', sep=',',
                            index=False)

# result = df_dly_null.append(df_dly_pos, ignore_index=True)
print(final_merged_dataset.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1330548 entries, 0 to 1330547
# Data columns (total 10 columns):
# index                  1330548 non-null int64
# searchTerm             1329176 non-null object
# product_id             1330548 non-null int64
# product_impressions    1330548 non-null int64
# Product_clicks         1330548 non-null int64
# cart_adds              1330548 non-null int64
# order                  1330548 non-null int64
# CTR                    1330548 non-null float64
# ATR                    1330548 non-null float64
# conv                   1330548 non-null float64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 101.5+ MB
# None
#                                          searchTerm     product_id  \
# 0                                childrens lap desk  6000065495247
# 1                          rice cooker with steamer  6000196308548
# 2  Depend Silhouette For Women Briefs, Small/Medium  6000188021783
# 3                                power it generator  6000196423433
# 4                    brother cp-7500 sewing machine  6000188906792
#
#    product_impressions  Product_clicks  cart_adds  order       CTR  ATR  conv
# 0                    2               1          0      0  0.500000  0.0   0.0
# 1                    3               1          0      0  0.333333  0.0   0.0
# 2                    1               1          0      0  1.000000  0.0   0.0
# 3                   11               3          0      0  0.272727  0.0   0.0
# 4                    2               1          0      0  0.500000  0.0   0.0

# %%
#pd.read_csv('final_merged_dataset_mthly2.csv')
df2 = pd.read_csv('final_merged_dataset_mthly2.csv', encoding='latin-1')

# %%
df2
# Out:
#                                                searchTerm     product_id  \
# 0                                      childrens lap desk  6000065495247
# 1                                rice cooker with steamer  6000196308548
# 2        Depend Silhouette For Women Briefs, Small/Medium  6000188021783
# 3                                      power it generator  6000196423433
# 4                          brother cp-7500 sewing machine  6000188906792
# 5                                         shower liner 80  6000195530630
# 6                                                   knorr  6000136119373
# 7                    logitech case keyboard for ipad mini  6000192600004
# 8                                           pots and pans  6000197323653
# 9                                             tablet case  6000196965688
# 10                                     kids swimming vest  6000196214086
# 11                                             phone case  6000196907029
# 12                               graco elite glider swing  6000111967288
# 13                                              BARBEQUES  6000196973441
# 14                                   sterling chain snake  6000016938728
# 15                                         corelle dishes  6000016950265
# 16                                          school locker  6000196172083
# 17                                           storage beds  1255120730359
# 18                                               dog dish       10198180
# 19                                           parsley seed  6000026842215
# 20                             thermos smart water bottle  6000196135555
# 21                                                 ol roy  6000195391284
# 22                                      gerber baby socks  6000196148215
# 23                                                  duvet  6000196642814
# 24                                      sunny health bike  6000193040549
# 25                                        baby sterilizer  6000016940184
# 26                                    finesse conditioner  6000109165657
# 27                                           utility cart  6000189905326
# 28                                         toys for girls  6000196171715
# 29                                                egg toy  6000196611185
# ...                                                   ...            ...
# 1330518                              baby toys 0-12 month  6000196194340
# 1330519                               toddler bath sponge  6000196127150
# 1330520                              spray hand sanitizer  6000196744056
# 1330521                           washable training pants  1455224923245
# 1330522                                mens trainer shoes  6000196405674
# 1330523                                          japanese  6000134323805
# 1330524                 carpet sweepers in port coquitlam  6000001836136
# 1330525                                  crayola coloured  6000016937831
# 1330526                         portable air conditioners  6000197315109
# 1330527                                         shin bowl  6000136119404
# 1330528                                    queen mattress  6000188743242
# 1330529                                        gluesticks  6000161803596
# 1330530                                             rings  6000188710627
# 1330531                              naturana nursing bra  6000196872058
# 1330532                                         Dome Tent  6000196489633
# 1330533                            huggies training pants  1255066059558
# 1330534                                   fitness machine  6000195933044
# 1330535                               learning essentials  6000055212382
# 1330536                                           palmers  6000192741408
# 1330537                                             LG 43  6000196768529
# 1330538                            double/queen sheet set  6000195530184
# 1330539                 t-fal avante pro electric toaster  6000016941482
# 1330540                                   heat protection  6000188114881
# 1330541                                      whey isolate  6000195557114
# 1330542                                       women razor  6000016938072
# 1330543                                             mk360  6000197090300
# 1330544                                             Trail  6000196462181
# 1330545                              flintstones vitamins  6000016949976
# 1330546                                         door stop  6000104225720
# 1330547                             case mate iphone case  6000196398542
#
#          product_impressions  Product_clicks  cart_adds  order       CTR  \
# 0                          2               1          0      0  0.500000
# 1                          3               1          0      0  0.333333
# 2                          1               1          0      0  1.000000
# 3                         11               3          0      0  0.272727
# 4                          2               1          0      0  0.500000
# 5                          3               1          0      0  0.333333
# 6                        113               9          2      0  0.079646
# 7                          3               1          0      0  0.333333
# 8                          2               2          0      0  1.000000
# 9                        198              10          2      1  0.050505
# 10                         7               3          1      0  0.428571
# 11                        11               1          0      0  0.090909
# 12                         2               1          0      0  0.500000
# 13                         2               1          0      0  0.500000
# 14                         2               1          0      0  0.500000
# 15                       137              11         12      0  0.080292
# 16                         4               1          0      0  0.250000
# 17                         6               3          0      0  0.500000
# 18                         7               2          0      0  0.285714
# 19                         1               1          0      0  1.000000
# 20                         2               1          0      0  0.500000
# 21                         2               1          0      0  0.500000
# 22                         1               1          0      0  1.000000
# 23                      1249              16          2      0  0.012810
# 24                         1               1          0      0  1.000000
# 25                        16               2          1      1  0.125000
# 26                         4               2          1      0  0.500000
# 27                        61               4          0      0  0.065574
# 28                       344               3          4      0  0.008721
# 29                         4               2          1      0  0.500000
# ...                      ...             ...        ...    ...       ...
# 1330518                  158               6          2      0  0.037975
# 1330519                    2               1          0      0  0.500000
# 1330520                    1               1          0      0  1.000000
# 1330521                    4               1          0      0  0.250000
# 1330522                    3               1          0      0  0.333333
# 1330523                    5               1          1      1  0.200000
# 1330524                    2               1          0      0  0.500000
# 1330525                    1               1          0      0  1.000000
# 1330526                   86               7          1      0  0.081395
# 1330527                    1               1          0      0  1.000000
# 1330528                  960              29          4      1  0.030208
# 1330529                    3               1          0      0  0.333333
# 1330530                    2               1          0      0  0.500000
# 1330531                    2               0          1      0  0.000000
# 1330532                    2               1          1      0  0.500000
# 1330533                    1               0          1      0  0.000000
# 1330534                    1               1          0      0  1.000000
# 1330535                    2               1          0      0  0.500000
# 1330536                   27               1          0      0  0.037037
# 1330537                    2               1          0      0  0.500000
# 1330538                    9               2          2      0  0.222222
# 1330539                    1               0          1      0  0.000000
# 1330540                   15               7          2      0  0.466667
# 1330541                   72               9          4      0  0.125000
# 1330542                    3               1          0      0  0.333333
# 1330543                    3               2          1      0  0.666667
# 1330544                    4               1          0      0  0.250000
# 1330545                   13               2          1      0  0.153846
# 1330546                   57               6          0      0  0.105263
# 1330547                    4               1          0      0  0.250000
#
#               ATR      conv
# 0        0.000000  0.000000
# 1        0.000000  0.000000
# 2        0.000000  0.000000
# 3        0.000000  0.000000
# 4        0.000000  0.000000
# 5        0.000000  0.000000
# 6        0.017699  0.000000
# 7        0.000000  0.000000
# 8        0.000000  0.000000
# 9        0.010101  0.005051
# 10       0.142857  0.000000
# 11       0.000000  0.000000
# 12       0.000000  0.000000
# 13       0.000000  0.000000
# 14       0.000000  0.000000
# 15       0.087591  0.000000
# 16       0.000000  0.000000
# 17       0.000000  0.000000
# 18       0.000000  0.000000
# 19       0.000000  0.000000
# 20       0.000000  0.000000
# 21       0.000000  0.000000
# 22       0.000000  0.000000
# 23       0.001601  0.000000
# 24       0.000000  0.000000
# 25       0.062500  0.062500
# 26       0.250000  0.000000
# 27       0.000000  0.000000
# 28       0.011628  0.000000
# 29       0.250000  0.000000
# ...           ...       ...
# 1330518  0.012658  0.000000
# 1330519  0.000000  0.000000
# 1330520  0.000000  0.000000
# 1330521  0.000000  0.000000
# 1330522  0.000000  0.000000
# 1330523  0.200000  0.200000
# 1330524  0.000000  0.000000
# 1330525  0.000000  0.000000
# 1330526  0.011628  0.000000
# 1330527  0.000000  0.000000
# 1330528  0.004167  0.001042
# 1330529  0.000000  0.000000
# 1330530  0.000000  0.000000
# 1330531  0.500000  0.000000
# 1330532  0.500000  0.000000
# 1330533  1.000000  0.000000
# 1330534  0.000000  0.000000
# 1330535  0.000000  0.000000
# 1330536  0.000000  0.000000
# 1330537  0.000000  0.000000
# 1330538  0.222222  0.000000
# 1330539  1.000000  0.000000
# 1330540  0.133333  0.000000
# 1330541  0.055556  0.000000
# 1330542  0.000000  0.000000
# 1330543  0.333333  0.000000
# 1330544  0.000000  0.000000
# 1330545  0.076923  0.000000
# 1330546  0.000000  0.000000
# 1330547  0.000000  0.000000
#
# [1330548 rows x 9 columns]

# %%
row_counts = {}
for row in df2:
        res.append(df2.get_value(r))

# %%
for i in range(10):
    print(df2.columns.value_counts())
# Out:
# CTR                    1
# product_id             1
# Product_clicks         1
# searchTerm             1
# cart_adds              1
# order                  1
# conv                   1
# product_impressions    1
# ATR                    1
# dtype: int64

# %%
row_counts = {}
for i in df2['searchTerm']:
    if i in row_counts:
        row_counts[i]+=1
    else:
        row_counts[i]=1

# %%
row_counts
# Out:
# {'childrens lap desk': 3,
#  'rice cooker with steamer': 1,
#  'Depend Silhouette For Women Briefs, Small/Medium': 1,
#  'power it generator': 3,
#  'brother cp-7500 sewing machine': 2,
#  'shower liner 80': 3,
#  'knorr': 83,
#  'logitech case keyboard for ipad mini': 3,
#  'pots and pans': 127,
#  'tablet case': 37,
#  'kids swimming vest': 7,
#  'phone case': 28,
#  'graco elite glider swing': 1,
#  'BARBEQUES': 1,
#  'sterling chain snake': 2,
#  'corelle dishes': 19,
#  'school locker': 3,
#  'storage beds': 62,
#  'dog dish': 17,
#  'parsley seed': 1,
#  'thermos smart water bottle': 2,
#  'ol roy': 60,
#  'gerber baby socks': 3,
#  'duvet': 130,
#  'sunny health bike': 1,
#  'baby sterilizer': 10,
#  'finesse conditioner': 4,
#  'utility cart': 32,
#  'toys for girls': 377,
#  'egg toy': 3,
#  'AIRPORT PASSENGER TERMINAL': 1,
#  'real technique brushes': 14,
#  'barbie bike': 9,
#  'sally hansen nail polish': 33,
#  'sterilite 45': 1,
#  'men jean shorts': 1,
#  'ivory': 70,
#  'gillette fusion razors': 1,
#  'minion blanket': 5,
#  'sterilite with drawers': 3,
#  'cabbage salad': 6,
#  'truvia': 18,
#  'foodsaver accessories': 1,
#  'shave gel': 27,
#  'jeggings womens': 12,
#  'brown casual shoe men': 1,
#  'Variety Pack Dog Food 6 x 283 g': 1,
#  'GREAT VALUE CHIPS': 41,
#  'zuru fidgit cube': 5,
#  'gillette razor': 12,
#  'sensitive baby formula': 1,
#  'EverCurl': 3,
#  'double air bed with pump': 9,
#  'santoku': 3,
#  'table stand': 4,
#  'usb': 79,
#  'dry erase wax crayon': 1,
#  'swim top women': 4,
#  'protein powder vega': 3,
#  'beatles': 45,
#  'baby dolls': 65,
#  'BLSTMG-RAS-033': 1,
#  'vacuum': 184,
#  'capris': 51,
#  'rod kit curtain': 4,
#  'Instax': 9,
#  'portable air conditioner exhaust kit': 1,
#  'leapfrog': 52,
#  'manure': 3,
#  'wing chair slipcovers': 13,
#  'women lon sleeve vest': 1,
#  'power bars': 32,
#  'black series': 35,
#  'portable gas fire': 6,
#  'bananas': 76,
#  'scooby': 13,
#  'charging cable micro usb 3 m': 1,
#  'blender': 112,
#  'long body pillows': 11,
#  'neutrogena clear': 1,
#  'cat litter': 99,
#  'steering cover': 4,
#  'toilet': 86,
#  'cruiser': 25,
#  'mini fridges whirlpoool energy': 3,
#  'burts bees vani': 60,
#  'nose grooming kit': 1,
#  'panier de basketball': 18,
#  'pantene': 83,
#  'star trek beyond': 5,
#  'canada 150 flags': 3,
#  'vanilla': 89,
#  'Mirror': 34,
#  'Dehumidifier': 24,
#  '42x48 garbage bag': 13,
#  'corner tv stands': 25,
#  'gerber snack': 6,
#  'baby clothes boys 18-24 months': 69,
#  'Gazebo Canopy': 2,
#  'Lounge Cushion black': 1,
#  'clear glass vase': 2,
#  'friskies wet food for cats': 49,
#  'drawer': 152,
#  '20 fl oz cetaphil moisturizing lotion fragrance free': 1,
#  'hiking purathletics': 1,
#  'kids food': 17,
#  'wigglin water sprinkler': 1,
#  'george white': 1,
#  'shelves with basket': 60,
#  'paper liner': 2,
#  'rompers baby girl': 13,
#  'filter': 62,
#  'baby alive dolls': 5,
#  'lunch meat': 64,
#  'cases of water': 60,
#  'outdoor living furniture': 4,
#  'play doh party': 1,
#  'essential oils': 13,
#  'South Shore Storit 2-Pack Patterned Fabric Storage Baskets from Walmart': 1,
#  'oxiclean arm and hammer': 1,
#  'round table top': 2,
#  'yugioh': 61,
#  'waterboy': 1,
#  'jolly jumper nursing pillow': 2,
#  'drywall anchor screw': 8,
#  'snap & pour': 1,
#  'matrix dvd': 2,
#  'chopping boards': 1,
#  'silicone placemat': 2,
#  'doctor who tom baker': 3,
#  'kids shoes': 138,
#  'pressure mount curtain rod': 4,
#  'trailer cover': 15,
#  'baby wash cloth': 32,
#  'great value drain cleaner': 1,
#  'cling wrap glad': 5,
#  'wedco versaflex spout': 1,
#  'hair tools': 25,
#  'kingsport': 2,
#  'sony over ear headphones': 1,
#  'memory foam': 69,
#  'spider man bed for kids': 3,
#  'key safe': 2,
#  'clear garbage bags large': 4,
#  'rosewater hand soap': 2,
#  'area rug': 239,
#  'frozen': 360,
#  'lego ghost': 1,
#  'vacuum cleaner': 111,
#  '6000196206230': 1,
#  'little tike muskoka chair': 1,
#  'pencils case': 5,
#  'Spacesaver': 1,
#  'Cuisinart baby food maker': 1,
#  'bar counter stools': 1,
#  'clinical': 34,
#  'wet cat food': 109,
#  'curtain rod for bathroom': 3,
#  'exerpeutic recumbent bike': 1,
#  'patio throw pillows': 1,
#  'shoe storage': 60,
#  'curry japan': 1,
#  'toy flashlight': 2,
#  'rimmel eye definer': 1,
#  'serum': 24,
#  'deep pickle': 3,
#  'duffle bag': 65,
#  'color radiance': 3,
#  'breton crackers': 20,
#  'shampoo conditioner': 63,
#  'Goldfish': 8,
#  'gerber nestle': 3,
#  'nuk': 27,
#  'synthetic motor oil': 12,
#  'beautyand the beast dresses': 1,
#  'mousse': 38,
#  'makeup mirrors': 6,
#  'samsung galaxy tab e 8 cases': 3,
#  'kettle': 104,
#  'cahier canada 32 pages': 2,
#  'south shore crystal': 3,
#  'repellant coil': 1,
#  'toys for girls ages1-3': 8,
#  'toiletbrush': 4,
#  'black beds': 4,
#  'outdoor park bench': 3,
#  'pj masks watch': 5,
#  'dry roasted peanuts': 3,
#  'lens hood': 1,
#  'sardines brunswick': 6,
#  'dash cameras': 5,
#  'Bread': 66,
#  'under tge bed storage on wheels': 1,
#  'sharpie tank': 2,
#  'fresh express': 6,
#  'splash pants': 3,
#  'chest freezers': 15,
#  '6x8 speakers': 2,
#  'love songs': 3,
#  'iphone 6 case sale': 7,
#  '3D movies': 9,
#  'self inflating air mattress': 6,
#  'over ear headphones': 37,
#  'perfect total crunch': 1,
#  'air purifiers': 48,
#  'sunbeam 12 cup coffee maker': 4,
#  'finish agent': 1,
#  'Kiss InstaWave Automatic Curler': 1,
#  'canada 150 tshirts': 11,
#  'kids desks': 15,
#  'outside umbrella base': 3,
#  'mary': 61,
#  'bookcase': 172,
#  'wet wipes travel': 25,
#  'arm protector': 1,
#  'Preschool toys boys': 5,
#  'george lamb': 3,
#  'Sanders': 3,
#  'batteries': 171,
#  'newborn baby kits': 8,
#  'everlast heavy resist': 1,
#  'air canada suitcase': 2,
#  'saltwater trolling rod': 2,
#  'juice': 187,
#  'dinotrux die cast': 1,
#  'benches': 100,
#  'barbie': 306,
#  'future': 3,
#  'spf 15 sunscreen': 1,
#  'qtips': 8,
#  'fREE RUN': 1,
#  'herbal essence mousse': 4,
#  'Camera memory cards': 6,
#  'lighting pendants': 17,
#  'electric razors for men': 23,
#  'UPRIGHT VACUUM': 2,
#  'webber naturals D3 kids': 1,
#  'cd player portable': 64,
#  'sheets for a double bed': 3,
#  'floor baby': 1,
#  'white toy chest': 5,
#  'diapers size 6': 39,
#  'honeywell 14000 btu': 1,
#  'chlorine tabs': 2,
#  'vegetables frozen': 8,
#  'washer pressure': 5,
#  'pain reliever spray': 2,
#  'pirate hook': 3,
#  'vacuum food sealer rolls': 2,
#  'sterilite tower': 9,
#  'blaster': 28,
#  'Warming tray': 4,
#  'clear bags 30x38': 2,
#  'Frigidaire 50-Pint Dehumidifier': 1,
#  'baggy for kids for shopping': 2,
#  'electric grill': 29,
#  'iron maiden': 8,
#  'tail': 60,
#  'folding screen': 6,
#  'Measuring tape': 3,
#  'bath caterpillar': 1,
#  'SNAUSAGES': 2,
#  'chrome exhaust': 1,
#  'guards': 2,
#  'hilroy 3 inch binders': 1,
#  'mpow car mounts': 2,
#  'Eric Clapton vinyl': 6,
#  'black legging capri': 1,
#  '1050 TI': 1,
#  'mod baby 3 in 1 toddler rail': 9,
#  'mens bikes': 37,
#  'car and booster seats': 7,
#  'otterbox galaxy j1': 2,
#  'Outdoor umbrella': 1,
#  'Decongestantg Nasal Spray with Moisturizers': 4,
#  'detergent laundry': 115,
#  'pine needl oil': 1,
#  'pokemon cards mega charizard ex': 15,
#  'great value': 559,
#  'Dehydrator': 10,
#  '4 burner bbq': 3,
#  'twin duvet': 54,
#  'graphic t-shirt': 2,
#  'little pony': 40,
#  'bic assorted': 31,
#  'black and white sheets': 2,
#  'balls': 63,
#  'pampers cruisers 3': 2,
#  'wall air conditioner': 57,
#  'onesies boys 18-24 months': 3,
#  'manicure set': 7,
#  'screen protectors for tablets': 2,
#  'small toys': 8,
#  'lord of the rings Blu-ray': 2,
#  'iphone 5c cases': 9,
#  'BAKING SHEET': 4,
#  'bag': 155,
#  'bedroom dresser': 18,
#  'minwax wood stain small': 1,
#  'pom pom balls': 23,
#  'kiss cd': 10,
#  'cutting boards in store': 7,
#  '64gb memory card': 2,
#  'cannon printer ink 245': 3,
#  'verona rug': 1,
#  '242374': 1,
#  'potty training seat that goes on toilet': 17,
#  'olive oil bottle pouring spouts': 1,
#  'kids bike helmets': 17,
#  'bed in a bag': 194,
#  'monitors': 71,
#  'buttons': 83,
#  'lounge lawn chair': 3,
#  'salon cream': 1,
#  'tweezers': 30,
#  'sunscreen ombrelle': 1,
#  'insect repellent in outdoor living': 31,
#  'meguiars scratch': 1,
#  'all bran cereal': 10,
#  'tank': 44,
#  'children table and chair set': 13,
#  'dyson cooling fan': 10,
#  'hot air': 3,
#  'house fan seabreeze': 2,
#  'sunscreen oil free': 2,
#  'polk bluetooth speakers': 1,
#  'Long range digital TV antenna': 3,
#  'glad roommate garbage bags': 34,
#  'eye cream': 35,
#  'black cutlery': 4,
#  'cake': 121,
#  'jegging': 18,
#  'comforter sets': 155,
#  'big drink dispenser': 3,
#  'anti-dandruff shampoo': 9,
#  'tiger grill pan': 1,
#  'breadsticks': 8,
#  'schultz plant food': 2,
#  'bottle sterilizer': 13,
#  'auxiliary cable': 8,
#  'shampoo for dyed hair': 1,
#  'oreal lipstick': 17,
#  'baby clothes for boys 6-12 moths': 84,
#  'sports bra pack': 4,
#  'plus': 18,
#  'shoe shelf': 9,
#  'Table cloth': 8,
#  'light bulb type a19': 3,
#  'farm hoppers animal bouncers': 8,
#  'toronto raptors big and tall t-shirts': 1,
#  'rocks': 63,
#  'madonna cd': 6,
#  'cruiser bike': 41,
#  'clean and clear wipes': 2,
#  'camp barbeque': 2,
#  'minion pajamas': 4,
#  'equate unscented baby wipes': 3,
#  'bed bug pillow': 1,
#  'tACO SEASONING': 15,
#  'Frigidaire air conditioner': 2,
#  'feather duvets': 6,
#  'Water shoes': 6,
#  'fishing reel': 42,
#  'crib mattress protector': 14,
#  'large food storage': 3,
#  'extendable dining table': 1,
#  'metal hack saw': 3,
#  'womans hood': 1,
#  'broth': 51,
#  '30190466': 1,
#  'c batteries charger': 1,
#  'roots touch ups': 2,
#  'whey': 40,
#  'games': 285,
#  'girls jumpsuit': 2,
#  'sunrype fruit to go 72 pack': 3,
#  'sour cherries': 3,
#  'darts': 60,
#  'waffle maker': 42,
#  'sun screen': 87,
#  'bestway pool cover': 3,
#  '1inch memory foam matteress': 2,
#  'fashion dolls': 16,
#  'hats': 38,
#  'bathroom blue': 1,
#  'frozen juice pack': 27,
#  'speed stick': 24,
#  'hamilton beach blender': 17,
#  'paw patrol costume': 4,
#  'xbox one kinect': 6,
#  'vtech go! go! smart wheels english': 3,
#  'heated shower': 1,
#  'cookie filled': 1,
#  'dr brown': 48,
#  'usb headset ac 850': 1,
#  'cosmetic scissors': 1,
#  'oral b for kids': 2,
#  'SLINKY': 1,
#  'face painting': 1,
#  'white and gold room furniture': 1,
#  'dishwasher': 77,
#  'fructis': 73,
#  'Braun electric shaver': 3,
#  'waterproof mattress pad': 6,
#  'sparkling drinks': 15,
#  'en jeans': 3,
#  'oral-b dual clean replacement': 1,
#  'dvd-r': 14,
#  'one a day multivitamin': 1,
#  '18 girls bike': 4,
#  'fidget spinner led light': 6,
#  'vaccum accessory': 2,
#  'gift': 24,
#  'betty crocker icing': 60,
#  'skip bo card game': 1,
#  'womens sleepwear': 85,
#  'boots': 70,
#  'tooth brush medium': 7,
#  'jerk chicken marinade': 2,
#  'blue ray movie cinderalla': 5,
#  'soccer': 72,
#  'samsung tablet a': 4,
#  'sauce great value': 4,
#  'glass storage': 31,
#  'sheet set': 132,
#  'coffee pod filters': 1,
#  'gaming mouse': 49,
#  'pool patch kit': 5,
#  'linguine pasta': 3,
#  'snacks in bulk': 39,
#  'oreal paris excellence': 5,
#  'we furniture 52 high boy tv stand': 2,
#  'burts bees face lotion': 4,
#  'padlock': 53,
#  'LITTER': 60,
#  'panasonic 8 function multicooker': 1,
#  'duvet covers': 109,
#  'washington capitals': 1,
#  'hometrends rurt-resistant shower caddy': 1,
#  'wrangler performance jeans': 1,
#  'plum tomatoes': 62,
#  'cat food canned friskies': 2,
#  'fabric freshener': 5,
#  'monitor splitter': 1,
#  'bike light': 10,
#  'carnation good start': 5,
#  'terra cotta': 60,
#  'baby food': 286,
#  'iphone 7 plus case': 66,
#  'kids hoddie towel': 5,
#  'game console': 9,
#  'kitchenaid kettle': 6,
#  'wilton cake stand': 1,
#  'spray paints': 15,
#  'womans bike shorts': 3,
#  'DEEP FRYERS': 1,
#  'gillette fusion chill': 1,
#  'water bottle kids': 9,
#  'canister vacuum bags': 1,
#  'true match super blendable powder': 1,
#  'goosebumps': 19,
#  'rollover': 28,
#  'solar garden lights': 19,
#  'gravy poutine': 4,
#  'TENTS': 68,
#  'k cup coffee pods': 31,
#  'wine': 54,
#  'acto': 5,
#  'disposable': 16,
#  'Lego girl': 23,
#  'neck massagers': 3,
#  'universal laptop cord': 1,
#  'monster high plush': 1,
#  'Gillette Mach3': 1,
#  'ceramic non-stick cookware': 4,
#  'my life  dolls': 1,
#  'light caramel brown hair dye': 2,
#  'dirt bike helmet': 2,
#  'glass tea world etched mug': 3,
#  'Playstation 4': 16,
#  'sewing tool': 2,
#  'sonic': 17,
#  'water fountains outdoor': 9,
#  'wine aerator': 7,
#  'maxwell house french vanilla': 1,
#  'kitchenaid cutting board': 2,
#  'comforter king': 14,
#  'medpro urinal': 1,
#  'playstation 4': 212,
#  'glass': 86,
#  'Freezer bags': 3,
#  'crops': 2,
#  'pasta catelli': 61,
#  'Full Mates Platform with storage': 1,
#  'retractable pencil eraser': 3,
#  'frozen pillow': 2,
#  'non fat': 2,
#  'cfl': 67,
#  'tremclad rust paint': 17,
#  'air conditioning for cars': 3,
#  'travel bag': 48,
#  'camping coolers': 17,
#  'argan oil for hair': 16,
#  '215 70 r16': 1,
#  'wardrobe storage': 32,
#  'storage cabinets on wheels': 2,
#  'mccormick seasonings': 4,
#  'Sally Hansen': 7,
#  'Inkjoy gel pens': 1,
#  'fan heater': 8,
#  'led monitor hdmi': 4,
#  'upholstery cleaner': 10,
#  'dips': 52,
#  'toddler rockers': 1,
#  'Hair dryer': 12,
#  'african american movies': 1,
#  'mango pineapple': 2,
#  'Telescope': 13,
#  'printer ink hp 21': 2,
#  'Cashmere': 2,
#  'spa': 42,
#  'the bfg': 2,
#  'vinyl': 127,
#  'alarm clocks': 49,
#  'papermate tip pen': 1,
#  'avengers blanket': 2,
#  'decor pillows': 24,
#  'george tshirts': 15,
#  'ceres': 10,
#  'germination': 1,
#  'DELTA MADISSON': 2,
#  'tables for living room': 70,
#  'king kong toys': 1,
#  'baby oil equate': 60,
#  'long handle dust pan': 2,
#  'rice bistro express': 3,
#  'tuna can': 63,
#  '2 x 5 mat': 4,
#  'giuseppe pizza': 8,
#  'milk 2%': 79,
#  '501287402232': 1,
#  'Pure Balance': 5,
#  'pantene clarifying shampoo': 2,
#  'avery label': 19,
#  'hanging flower pot': 5,
#  'diet pop': 28,
#  'dish detergent pods': 60,
#  'golds gym belt': 2,
#  'foldable canopy outdoor': 3,
#  'jamieson liquid fish oil': 1,
#  'Jacquard': 5,
#  'lady speed stick deodorant': 2,
#  'oreal matte lipstick': 1,
#  'tetley tassimo': 1,
#  'baby monitor video': 36,
#  'seat back organizer': 3,
#  'brassex': 82,
#  'Stroller': 29,
#  'bean bag chairs': 58,
#  'night stands': 68,
#  'womens sleep robe': 2,
#  'rugs under the dining table': 3,
#  'sticky vinyl shelf covering': 16,
#  'mat': 155,
#  'palm leaf bedding': 2,
#  'childrens sheet sets': 1,
#  'Lettuce': 4,
#  'beef': 132,
#  'special kitty kitty litter': 24,
#  'Annies': 61,
#  'exquisite form bra front': 1,
#  'ASUS NOTEBOOK&amp;nbsp;': 2,
#  'cat food indoor': 4,
#  'loose leaf ruled paper': 66,
#  'pine sol': 11,
#  'tank tops women': 90,
#  'dghp': 1,
#  'club house': 112,
#  'car polishing buffer machines on': 1,
#  'goody straight': 1,
#  'chocolate almonds': 47,
#  'George': 5,
#  'Waterpik Waterflosser Cordless plus': 1,
#  'mens hiking shoes': 4,
#  'berries': 83,
#  'passengers': 54,
#  'desks for teens': 55,
#  'eye glasses': 167,
#  'plastic storage bins big': 7,
#  'baby gate for stairs': 8,
#  'food saver': 41,
#  'socks': 294,
#  'bike girl huffy': 1,
#  'fate of the eight': 2,
#  'hotwheels': 79,
#  'camp chef double square cooking iron': 2,
#  'the beatles cd': 14,
#  'water play': 22,
#  'living room furniture': 68,
#  'pamperspull ups 3t-4t': 1,
#  'bath floral rug': 1,
#  'car seats baby': 14,
#  'coo?er': 7,
#  'dare beat paws morning snack': 1,
#  'underjams for girls': 2,
#  'reese sticks': 1,
#  'wall decor': 166,
#  'bar stool': 150,
#  'e.l.f.': 62,
#  'king size bed with storage': 1,
#  'mxwell house k-cups decaf coffee': 60,
#  'similac 3': 4,
#  'color correct pallet': 1,
#  'new nintendo 3ds charger': 1,
#  'towels and facecloths': 95,
#  'mats': 89,
#  'nursing poncho': 2,
#  'cool cover for mattress': 2,
#  'daler rowney acrylic paint': 4,
#  'binder 1.5': 23,
#  'bernardin': 54,
#  'shrunks': 10,
#  '40w diesel oil': 2,
#  'plastic fishing rod case': 4,
#  'electric toothbrush kids': 9,
#  'low calorie': 9,
#  'Olay Regenerist products': 2,
#  'great value chips veg crackers': 60,
#  'air filter for 2012 ml350': 1,
#  'picture frames': 147,
#  'silicone baking sheets': 3,
#  'sterilite storage bins': 29,
#  'tire pump': 16,
#  'black panther': 16,
#  'covered garment rack': 6,
#  'cream of mushroom soup': 17,
#  'remote control vehicles': 4,
#  'protein oatmeal': 2,
#  'pizza': 171,
#  'canning bath': 1,
#  'water shoes kids': 7,
#  'HP 92/93': 1,
#  'xbox 360 fifa 17': 1,
#  'conditioner garnier olive': 1,
#  'speakers': 175,
#  'metaslim coconut oil': 1,
#  'quinoa': 52,
#  'transfer sheets': 4,
#  'mens 5xb': 1,
#  'kitchen organization': 32,
#  'cat litter glade': 3,
#  'all season tires general tires': 1,
#  'sure lox': 2,
#  'bike': 266,
#  'kids bbq playsets': 60,
#  'sony am/fm radio': 1,
#  'head and shoulders 21 shampoo': 3,
#  'king size mattress': 23,
#  'always heavy': 6,
#  'BROOM': 7,
#  'Coffee table set': 2,
#  'neutrogena sunscreen sheer zinc': 1,
#  'ark': 4,
#  'coat rack': 73,
#  'womens plus size coat': 2,
#  'ps4 games': 277,
#  'mirror': 154,
#  'lunch kits': 33,
#  'robe women': 3,
#  'baby corn': 3,
#  'packing tape': 71,
#  'Breakfast grill': 2,
#  'car bedding': 2,
#  'video game console': 15,
#  '10202660': 1,
#  'tie out': 8,
#  'bed comforter/sheet sets twin': 11,
#  '24 papermate': 1,
#  'earl gray': 19,
#  'Gillette Fusion ProShield': 6,
#  'rolling bar cart': 3,
#  'mens dickies pants': 7,
#  'raw unfiltered apple cider vinegar': 5,
#  'tasters choice instant coffee': 3,
#  'litter': 94,
#  'Patio table and 6 chairs covers': 18,
#  'petmate dog cage': 1,
#  'super nintendo 1991': 1,
#  'cars 3': 163,
#  'serving dish': 6,
#  'water teether': 3,
#  'classico': 38,
#  'kotex': 50,
#  'Bakeware': 6,
#  'weather radio': 5,
#  'avent': 94,
#  'carpets,and area rugs': 188,
#  'Graco Modes Click Connect Travel System - Davis': 5,
#  'dr schools shoes': 61,
#  'cubby organizers white': 12,
#  'post-it': 35,
#  'tv antennas': 25,
#  '10148940': 1,
#  'peppercorn': 8,
#  'tv stand': 277,
#  'portable dvd player': 38,
#  'tmnt party': 7,
#  'Shelf Storage unit': 10,
#  'cuisinart SS-700 filter': 2,
#  'vtech toys': 54,
#  'water tubes price': 1,
#  'easy liner': 30,
#  'vitamin e drops': 1,
#  'marvel toys': 21,
#  'hair dye loreal bright colours': 1,
#  'toy  register': 1,
#  'aluminium cot': 1,
#  'square cake pan': 2,
#  'lego movie decor': 3,
#  'nem electric shaver': 3,
#  'command': 59,
#  'tooth paste': 88,
#  'secret deodorant for women': 7,
#  'gloves for dishes': 63,
#  'plant pots': 130,
#  'revlon hd': 3,
#  'marine radio': 1,
#  'Nintendo 3ds': 16,
#  'Cosco Slim Fold High Chair': 1,
#  'duster refills': 6,
#  'toilet paper': 94,
#  'Bed in a bag queen': 2,
#  'paintings': 50,
#  'window  panel': 4,
#  'furreal bootsie': 1,
#  'KETCHUP': 28,
#  'vacuum cleaners bissell': 12,
#  'above ground swimming pools 14x42': 25,
#  'ironing': 21,
#  'carry on baggage': 5,
#  'garbage can for kitchen': 1,
#  'digital watch': 57,
#  'parents choice baby wipes': 11,
#  'bags': 160,
#  'Pools': 30,
#  'mens dove deoderant': 60,
#  'glass loaf pan': 3,
#  'St. Ives Timeless Skin Collagen Elastin Facial Moisturizer': 1,
#  'pokemon cards': 185,
#  'antacid tablets': 4,
#  'childrens life vest': 11,
#  'Fiskars 7&amp;ndash;12.ft Extendable Saw & Pruner Pole': 1,
#  'NESQUIK CEREAL': 1,
#  'reclining chair and ottoman': 2,
#  'baby sheets': 35,
#  'paradise': 5,
#  'dove nutritive solutions daily': 1,
#  'pokemon card': 99,
#  'skin cleanser': 61,
#  'bird toys': 40,
#  'surprise': 10,
#  'crosley radio': 3,
#  'barbie and chelsea pinapple summer dolll': 3,
#  'BATMAN BEDROOM': 2,
#  'kid bed in bag': 1,
#  'equate laxative': 3,
#  'samsung 24': 4,
#  'Oral b headbrush': 2,
#  'soft cookies': 27,
#  'storex 2-drawwer moible file cabinet with lock': 44,
#  'south shore fusion': 8,
#  '62883718620': 1,
#  'nintendo switch accessories': 35,
#  'PILATIES RESISTANCE TUBING': 1,
#  'lawn ornament': 40,
#  'lemonade': 52,
#  'duel hose air conditioner': 2,
#  'pedigree dog food': 60,
#  'grocery online and delivery': 490,
#  'deodorant ladies': 58,
#  'off bug spray': 18,
#  'microsoft controller': 10,
#  'samsung android tablet': 2,
#  'ink cartridge': 86,
#  'fedora': 1,
#  'girls clothes peppa pig': 1,
#  'patio': 203,
#  'bright stars toys': 12,
#  'funtainer': 23,
#  'curtain rods decorative under $15.00': 4,
#  'bar soap dishes': 60,
#  'splatter screen': 9,
#  'night table': 87,
#  'NESTEA': 1,
#  'cover girl sg smoothers': 1,
#  'unscented baby wipes': 8,
#  'apple iphone 7': 2,
#  'cd storage': 42,
#  'cat toys': 73,
#  'queen': 44,
#  'minute rice ready to go': 4,
#  'Dawn Of The Dragon Racers (Bilingual)': 1,
#  'south shore night stand': 24,
#  'polident denture': 1,
#  'groceries that can be delivered': 174,
#  'computers': 89,
#  'black pants men': 4,
#  'dish sets': 89,
#  'kelloggs corn flakes': 4,
#  'switch': 95,
#  'fake nail': 1,
#  'soft rug': 1,
#  'foot deodorant spray': 1,
#  'clothing clips': 1,
#  'kraft dressing': 44,
#  'level': 61,
#  'curl': 26,
#  'knee pads and elbow pads youth 12': 59,
#  'Dungeons and Dragons, game': 1,
#  'queen bed in a bag': 38,
#  'soccer ball': 33,
#  'watch': 237,
#  'curtains 63 inches long': 1,
#  'fitter crib bed sheets': 1,
#  'Mountain bike': 10,
#  'masher': 11,
#  'screen protector iphone 6 plus': 3,
#  'hometrends Manmade Silk Almont Rug': 1,
#  'cubbie': 62,
#  'huggies pullups night': 2,
#  'books by kanet oke': 1,
#  'permanent markers': 33,
#  'invalid ring': 3,
#  'books for kids': 78,
#  'hinges': 13,
#  'colgate total gum health': 1,
#  'riding toys': 3,
#  'android tablet, 8Gb,': 2,
#  'white long john shirt': 1,
#  '00 philips': 1,
#  'sugar': 132,
#  'pajamas for boys': 22,
#  'greek': 64,
#  'party supplies': 152,
#  'polident false teeth cleanser': 1,
#  'vacuum irobot 8': 2,
#  'potassium supplement': 60,
#  'booster seats for carseat': 1,
#  'small appliances coffee makers': 9,
#  'play doh': 50,
#  'electric kettle': 58,
#  'invisible hairnet': 1,
#  'table & chairs outdoor': 60,
#  'travel car': 7,
#  'chair': 374,
#  'razors': 108,
#  'flushable wipes kids': 10,
#  'macintyre': 6,
#  'girls walking shoes': 4,
#  'guns n roses t shirt': 1,
#  'mattress cover': 54,
#  'serta 4 in 1': 1,
#  'stick on kitchen tile': 62,
#  'bras for women': 66,
#  'washer cleaner': 2,
#  'outdoor drying clothes': 1,
#  'can potatoes': 60,
#  'gazebo mosquito mesh': 1,
#  '9222479.': 1,
#  'white blinds': 17,
#  'coconut Water': 2,
#  'bicycle computers': 1,
#  'dyson animal': 7,
#  'womens dres pants': 2,
#  'rougemont apple': 1,
#  'jasmine conditioner': 1,
#  'twin bunk beds': 5,
#  'pink': 36,
#  'camp chairs': 34,
#  'storkcraft dresser': 10,
#  'bar glasses': 2,
#  'tricycles': 47,
#  'old spice shampoo': 9,
#  'golf cart drink holder': 1,
#  'toys for boys': 432,
#  'sonny rollins': 7,
#  'Remington shaver': 3,
#  'Tripod': 6,
#  'king sized microfiber': 1,
#  'Kids rain boots': 2,
#  'condiments': 27,
#  'dinner plates': 63,
#  'Barbie': 74,
#  'stainless steel pots': 9,
#  'slimer': 2,
#  'shampoo kids': 22,
#  'sure fit dorchester sofa slipcover': 1,
#  'pudding mix': 60,
#  '2 in 1 shampoo': 61,
#  'scuba diving gear': 10,
#  '24 month boy': 9,
#  'dole crushed pineapple': 2,
#  'throws and blankets': 26,
#  'Bathrobes': 2,
#  'backpack for school': 8,
#  'descendants 2 dvd': 4,
#  'cafe chairs': 1,
#  'gain': 81,
#  'sodastream': 46,
#  'baby formula nestle good start': 10,
#  'muscletech protein powder': 2,
#  'dora the explorer dolls': 2,
#  'toilet bowl cleaner brush': 5,
#  'wafer': 31,
#  'Blood pressure monitor': 17,
#  'xbox': 107,
#  'johnson baby powder': 6,
#  'fruit of the loom WOMEN UNDERWEAR': 4,
#  'coleman propane 16oz': 1,
#  'indoor outdoor cafe string light set': 1,
#  'face wash': 22,
#  'thermometers': 42,
#  'cassareep': 1,
#  'couch': 111,
#  'cube storage shelf': 10,
#  'water': 194,
#  'shower curtain': 148,
#  'baby feeders set': 1,
#  'straps': 31,
#  'brown rice': 72,
#  'trolls dolls': 8,
#  'complete series on dvd': 2,
#  'no contact thermometers': 1,
#  'Backpacks': 34,
#  'sony hdmi dvd player': 1,
#  'ice skates': 67,
#  'uncle bens rice': 57,
#  'ladies razors': 61,
#  'foam topper crib': 2,
#  'comfort water lounge': 1,
#  'disney infinity starter pack 1.0': 4,
#  'type c otg': 3,
#  'mens watches': 159,
#  'insulated coffee thermos': 5,
#  'Toaster oven': 24,
#  'princess lego': 8,
#  'kidco gate': 17,
#  'pokemon cards new gx boxes': 2,
#  'rings': 191,
#  'Revlon hair dryer': 3,
#  'ladies swim tops': 4,
#  'ladies watch': 67,
#  'soap dispenser aqua': 1,
#  'bamboo': 60,
#  'tuna cat food': 8,
#  'AIR mattress': 3,
#  'scosche car charger micro usb': 1,
#  'toiletry travel bag': 13,
#  'dolce gusto americano': 1,
#  'wedge maternity pillow': 4,
#  'memory game for toddlers': 1,
#  'PADDLE hair bruSH': 3,
#  'outside furniture cushions': 11,
#  'south shore white collections': 2,
#  'joes tasty travels almond': 1,
#  'non greasy feet balm': 4,
#  'pool ladders': 5,
#  'wall decals': 66,
#  'carseat': 135,
#  'campbells soup': 107,
#  'Dymo': 6,
#  'change tables': 24,
#  'rice cookers': 33,
#  'bar refrigerators': 12,
#  'bily baby gate': 3,
#  'womens underwear': 109,
#  'fine tip permanent marker': 3,
#  'molson canadian': 5,
#  'computer headsets': 8,
#  'Clif Crunch White': 1,
#  'canon ink cartridges 245-246': 7,
#  '5995019100': 1,
#  'ink and toner': 1,
#  'danby deep freezer': 8,
#  'south shore terra': 2,
#  'wiiu games': 5,
#  'freshmatic refill': 26,
#  'outlet saver': 1,
#  'roku': 11,
#  'kurig coffee machine': 42,
#  'side table': 189,
#  'helmets kids': 18,
#  'gates': 77,
#  'tommee nipple': 2,
#  'pedi care': 6,
#  'Kidilove Supersoft  Baby Wash Cloth': 2,
#  'mega double breech': 1,
#  'doll': 169,
#  'seat cushions in automotive': 2,
#  'joola ping pong table': 29,
#  ...}

# %%
highfreq_searchStrings = []
for j in row_counts:
    if row_counts[j] > 500:
        highfreq_searchStrings.append(j)

# %%
highfreq_searchStrings
# Out:
# ['great value', '0', 'food', 'school supplies', 'storage', 'camping']

# %%
row_counts['great value']
# Out:
# 559

# %%
row_counts['0']
# Out:
# 1372

# %%
row_counts['school supplies']
# Out:
# 517

# %%
row_counts['storage']
# Out:
# 539
